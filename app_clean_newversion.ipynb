# %% [markdown]
# # **INTRO**
#
# As an initial step in the project, we conducted a focused exploratory data analysis of the LEAF prompt dataset in order to understand its structure, quality, and semantic characteristics before making any embedding-related design choices. The dataset contains 20,000 records and 20 fields, with no missing values, which makes it suitable for a robust semantic retrieval pipeline. Our analysis examined the distribution of languages, categories, subcategories, difficulty levels, text lengths, placeholders, and tags, as well as the distinction between semantic fields and metadata. This preliminary stage was essential to ensure that the embedding strategy would be grounded in the actual properties of the corpus rather than selected arbitrarily.

# %%
import json
import pandas as pd
import numpy as np
from collections import Counter
import re

INPUT_FILE = r"LEAF-promptkaban-dataset\dataset.json"

with open(INPUT_FILE, "r", encoding="utf-8") as f:
    data = json.load(f)

print("Total records:", len(data))
print("Data structure type:", type(data))
print("First record keys:", list(data[0].keys()))
# Out:
# Total records: 20000
# Data structure type: <class 'list'>
# First record keys: ['id', 'author_reputation', 'version', 'fork_count', 'likes', 'upvotes', 'downvotes', 'views', 'uses', 'created_at', 'title', 'content', 'category', 'subcategory', 'tags', 'has_placeholders', 'placeholders', 'difficulty', 'language', 'target_model']

# %%
df = pd.DataFrame(data)
print("Dataset shape:", df.shape)
df.head(3)
print("DATA TYPES:")
print(df.dtypes)
print()

print("MISSING VALUES:")
print(df.isna().sum().sort_values(ascending=False))
# Out:
# Dataset shape: (20000, 20)
# DATA TYPES:
# id                   object
# author_reputation     int64
# version               int64
# fork_count            int64
# likes                 int64
# upvotes               int64
# downvotes             int64
# views                 int64
# uses                  int64
# created_at           object
# title                object
# content              object
# category             object
# subcategory          object
# tags                 object
# has_placeholders       bool
# placeholders         object
# difficulty           object
# language             object
# target_model         object
# dtype: object
#
# MISSING VALUES:
# id                   0
# author_reputation    0
# version              0
# fork_count           0
# likes                0
# upvotes              0
# downvotes            0
# views                0
# uses                 0
# created_at           0
# title                0
# content              0
# category             0
# subcategory          0
# tags                 0
# has_placeholders     0
# placeholders         0
# difficulty           0
# language             0
# target_model         0
# dtype: int64

# %% [markdown]
# **Dataset overview**
#
# The dataset contains **20,000 prompt records** and **20 fields**, providing a sufficiently large corpus for building and testing a semantic retrieval pipeline. The absence of missing values across all columns is particularly valuable, as it removes the need for imputation or record filtering before the embedding stage. The schema also shows a clear separation between textual, categorical, and behavioral metadata, which supports a modular design for downstream retrieval and rerankin

# %%
print("LANGUAGE DISTRIBUTION:")
print(df["language"].value_counts())
print()

print("TOP 20 CATEGORIES:")
print(df["category"].value_counts().head(20))
print()

print("TOP 20 SUBCATEGORIES:")
print(df["subcategory"].value_counts().head(20))
print()

print("DIFFICULTY DISTRIBUTION:")
print(df["difficulty"].value_counts())
print()

print("HAS_PLACEHOLDERS DISTRIBUTION:")
print(df["has_placeholders"].value_counts())
# Out:
# LANGUAGE DISTRIBUTION:
# language
# en    19991
# es        5
# fr        2
# no        1
# zh        1
# Name: count, dtype: int64
#
# TOP 20 CATEGORIES:
# category
# creative-writing    1556
# marketing           1257
# sales               1186
# legal                990
# customer-support     899
# design               891
# education            622
# data-analysis        596
# translation          531
# finance              428
# coding               404
# game-design          390
# cybersecurity        390
# research             383
# devops               365
# science-research     345
# localization         342
# productivity         333
# gaming               273
# recruiting           257
# Name: count, dtype: int64
#
# TOP 20 SUBCATEGORIES:
# subcategory
# ticket-responses            235
# contract-drafting           214
# cold-outreach               206
# character-development       194
# plot-structure              192
# ui-ux                       183
# follow-ups                  176
# fiction                     167
# dialogue                    147
# objection-handling          145
# scientific-communication    141
# worldbuilding               138
# branding                    130
# gdpr-compliance             127
# lead-qualification          126
# color-theory                125
# brand-identity              123
# chatbot-flows               116
# social-media                116
# experiment-design           115
# Name: count, dtype: int64
#
# DIFFICULTY DISTRIBUTION:
# difficulty
# intermediate    8521
# beginner        6090
# advanced        4128
# expert          1261
# Name: count, dtype: int64
#
# HAS_PLACEHOLDERS DISTRIBUTION:
# has_placeholders
# False    17346
# True      2654
# Name: count, dtype: int64

# %% [markdown]
# **Core distributions for embeddings**
#
# **Language distribution**
#
# The corpus is overwhelmingly **English-dominant** *(19,991 out of 20,000 records)*, with only a negligible number of prompts in other languages. This strongly supports the use of an English-focused embedding model, while suggesting that multilingual handling can be treated as an edge case rather than a primary design requirement.
#
# **Category distribution**
#
# The category distribution reveals a broad thematic spread, with strong concentration in domains such as creative writing, marketing, sales, legal, and customer support. This variety is important because the embedding space must capture meaning across multiple domains rather than within a single narrow topic. At the same time, the presence of dominant categories may bias retrieval quality if evaluation queries are not selected carefully across the corpus.
#
# **Subcategory distribution**
#
# Subcategories appear more fine-grained and operationally informative than top-level categories. Labels such as ticket-responses, contract-drafting, cold-outreach, and plot-structure suggest that the dataset is not only topically diverse but also organized around task intent, which may be beneficial for semantic disambiguation when prompts are short or underspecified.
#
# **Difficulty distribution**
#
# The dataset is centered around intermediate-level prompts, followed by beginner, advanced, and expert prompts. This indicates that the corpus mostly represents practical, applied requests rather than highly specialized expert-only prompts. For embeddings, this matters because semantic variation is likely driven more by task formulation and domain vocabulary than by technical depth alone.
#
# **Placeholder distribution**
#
# Most prompts **do not contain placeholders**, while a meaningful minority does. This suggests that placeholders are not universal enough to define the corpus, but they are common enough to deserve explicit consideration during preprocessing. The embedding pipeline should therefore remain robust to both fully specified prompts and reusable template-style prompt

# %%
df["title_len_chars"] = df["title"].fillna("").astype(str).str.len()
df["content_len_chars"] = df["content"].fillna("").astype(str).str.len()

df["title_len_words"] = df["title"].fillna("").astype(str).str.split().str.len()
df["content_len_words"] = df["content"].fillna("").astype(str).str.split().str.len()

print("TEXT LENGTH STATS:")
print(df[[
    "title_len_chars", "content_len_chars",
    "title_len_words", "content_len_words"
]].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95, 0.99]))
# Out:
# TEXT LENGTH STATS:
#        title_len_chars  content_len_chars  title_len_words  content_len_words
# count     20000.000000       20000.000000     20000.000000       20000.000000
# mean         29.839050         338.263600         4.389250          54.703300
# std          12.095531         250.593884         2.200381          46.813192
# min           1.000000           4.000000         1.000000           1.000000
# 25%          23.000000         127.000000         3.000000          24.000000
# 50%          30.000000         323.000000         4.000000          45.000000
# 75%          36.000000         452.000000         5.000000          67.000000
# 90%          43.000000         681.100000         7.000000         128.000000
# 95%          49.000000         854.000000         9.000000         162.000000
# 99%          65.000000        1091.000000        12.000000         207.000000
# max         200.000000        1441.000000        43.000000         272.000000

# %% [markdown]
# **Text length analysis**
#
# The length statistics show a clear asymmetry between the two main textual fields: ***titles are generally short***, while **contents are** substantially **longer** and more informative. On average, **titles contain roughly 4.4 word**s, whereas **contents contain about 54.7 words**, with a long upper tail extending beyond 200 words. This confirms that content is the main carrier of semantic information, while title functions more as a compressed cue than a complete description. Extremely short prompts and very long prompts coexist in the same corpus, which may create heterogeneity in embedding quality and should be considered during model selection and evaluation

# %%
def is_very_short(text, threshold=4):
    return len(str(text).split()) <= threshold

def has_all_caps(text):
    s = str(text)
    letters = [c for c in s if c.isalpha()]
    if not letters:
        return False
    upper_ratio = sum(c.isupper() for c in letters) / len(letters)
    return upper_ratio > 0.7

def has_informal_style(text):
    s = str(text).lower()
    patterns = [
        r"\bidk\b", r"\bwats\b", r"\bpls\b", r"\bwut\b", r"\bim\b",
        r"\bcuz\b", r"\btho\b", r"\bgimme\b", r"\babt\b", r"\blol\b"
    ]
    return any(re.search(p, s) for p in patterns)

df["title_very_short"] = df["title"].apply(is_very_short)
df["title_all_caps_style"] = df["title"].apply(has_all_caps)
df["title_informal_style"] = df["title"].apply(has_informal_style)

print("TITLE NOISE CHECK:")
print("Very short titles (%):", round(df["title_very_short"].mean() * 100, 2))
print("All-caps style titles (%):", round(df["title_all_caps_style"].mean() * 100, 2))
print("Informal-style titles (%):", round(df["title_informal_style"].mean() * 100, 2))
# Out:
# TITLE NOISE CHECK:
# Very short titles (%): 64.33
# All-caps style titles (%): 4.61
# Informal-style titles (%): 2.09

# %% [markdown]
# **Title quality / noise check**
#
# The title analysis indicates that a large share of titles are very short (over 64%), while all-caps and strongly informal forms are present but much less frequent. This pattern suggests that titles cannot be assumed to be consistently descriptive: in many cases they provide useful context, but in others they are vague, colloquial, or stylistically noisy. As a result, titles may enrich the embedding input, but they should not be treated as a reliable standalone semantic field.

# %%
df["n_placeholders"] = df["placeholders"].apply(lambda x: len(x) if isinstance(x, list) else 0)

print("PLACEHOLDER STATS:")
print(df["n_placeholders"].describe())
print()

all_placeholders = Counter()
for row in df["placeholders"]:
    if isinstance(row, list):
        all_placeholders.update(row)

print("TOP 30 PLACEHOLDERS:")
for ph, cnt in all_placeholders.most_common(30):
    print(f"{ph}: {cnt}")
# Out:
# PLACEHOLDER STATS:
# count    20000.000000
# mean         0.236650
# std          0.708076
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         10.000000
# Name: n_placeholders, dtype: float64
#
# TOP 30 PLACEHOLDERS:
# industry: 248
# company_name: 215
# topic: 213
# product_name: 174
# audience: 161
# tone: 141
# number: 90
# genre: 90
# language: 81
# subject: 59
# grade_level: 52
# jurisdiction: 50
# code_snippet: 38
# format: 35
# department: 35
# duration: 35
# context: 34
# target_language: 31
# product_type: 31
# customer_name: 29
# text_input: 27
# job_title: 25
# research_topic: 24
# setting: 24
# style: 22
# project_name: 22
# project_type: 21
# platform: 21
# role: 21
# target_audience: 20

# %% [markdown]
# **Placeholder analysis**
#
# The placeholder statistics show that the median prompt contains no placeholders, but the maximum reaches 10, confirming that some prompts are highly templated. The most frequent placeholders — such as industry, company_name, topic, product_name, and audience — capture domain-specific variables rather than arbitrary syntax. This means placeholders may preserve useful structural intent, especially in reusable business and professional prompts. Their treatment should therefore be cautious: removing them entirely could discard part of the prompt’s functional meaning.

# %%
df["n_tags"] = df["tags"].apply(lambda x: len(x) if isinstance(x, list) else 0)

print("TAG COUNT STATS:")
print(df["n_tags"].describe())
print()

all_tags = Counter()
for row in df["tags"]:
    if isinstance(row, list):
        all_tags.update(row)

print("TOP 50 TAGS:")
for tag, cnt in all_tags.most_common(50):
    print(f"{tag}: {cnt}")
# Out:
# TAG COUNT STATS:
# count    20000.000000
# mean         4.153300
# std          0.846307
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          7.000000
# Name: n_tags, dtype: float64
#
# TOP 50 TAGS:
# template: 469
# beginner: 409
# compliance: 352
# writing: 332
# documentation: 328
# feedback: 323
# analysis: 309
# email: 293
# python: 253
# small-business: 239
# dialogue: 237
# automation: 232
# marketing: 228
# branding: 228
# communication: 223
# basics: 219
# checklist: 218
# gdpr: 217
# strategy: 214
# hiring: 213
# help: 207
# planning: 204
# saas: 190
# best-practices: 187
# onboarding: 186
# statistics: 186
# architecture: 182
# worldbuilding: 181
# e-commerce: 179
# performance: 176
# fantasy: 171
# metrics: 169
# methodology: 169
# script: 167
# copywriting: 164
# questions: 162
# sql: 162
# follow-up: 162
# design: 161
# pricing: 159
# engagement: 159
# templates: 153
# comparison: 153
# review: 149
# structure: 147
# productivity: 147
# negotiation: 146
# startup: 144
# workflow: 136
# optimization: 133

# %% [markdown]
# **Tag analysis**
#
# Tags are relatively dense and well populated, with a median of **4 tags per prompt** and an upper bound of 7. The most frequent tags indicate recurring themes such as **templates, compliance, documentation, analysis, email, Python, and marketing**. This suggests that tags provide concise semantic descriptors that may complement the main text, particularly when the prompt itself is brief or underspecified. At the same time, tags are editorial metadata, so their contribution should be validated empirically rather than assumed to improve retrieval by default.

# %%
print("5 SHORTEST PROMPTS BY WORD COUNT:")
shortest = df.sort_values("content_len_words").head(5)
for _, row in shortest.iterrows():
    print("\nID:", row["id"])
    print("Title:", row["title"])
    print("Content:", row["content"])
    print("Category:", row["category"], "| Subcategory:", row["subcategory"])


print("\n 5 LONGEST PROMPTS BY WORD COUNT:")
longest = df.sort_values("content_len_words", ascending=False).head(5)
for _, row in longest.iterrows():
    print("\nID:", row["id"])
    print("Title:", row["title"])
    print("Content preview:", row["content"][:1200])
    print("Category:", row["category"], "| Subcategory:", row["subcategory"])
# Out:
# 5 SHORTEST PROMPTS BY WORD COUNT:
#
# ID: pk_16772
# Title: help pls
# Content: translate
# Category: translation | Subcategory: general-translation
#
# ID: pk_16680
# Title: help
# Content: help
# Category: translation | Subcategory: minimal-request
#
# ID: pk_06172
# Title: legal question
# Content: regulations
# Category: legal | Subcategory: regulatory-analysis
#
# ID: pk_07754
# Title: microservices help
# Content: microservices???
# Category: architecture | Subcategory: design-patterns
#
# ID: pk_06995
# Title: transcreation
# Content: transcreation
# Category: translation | Subcategory: transcreation
#
#  5 LONGEST PROMPTS BY WORD COUNT:
#
# ID: pk_16332
# Title: company wants to rebrand and i got put in charge
# Content preview: so basically my company is doing this whole rebrand and somehow i ended up being the project lead even though i have no formal design training i just have good taste apparently which is not the same as knowing how to execute a rebrand so im kinda panicking because theres like a whole process people go through for this and i dont know what the steps are also our old brand is so ingrained everywhere like on business cards and letterhead and vehicle wraps and uniforms and email signatures and our website and social media and product packaging and basically everywhere and how do you even begin to change all of that without like a year of work and a million dollars also my boss wants it done in like 3 months which seems impossible but maybe thats normal?? also we want to do user research or whatever to see if people even care about our brand which seems like overkill but also maybe smart?? also we need a new logo obviously but do we throw away the old one entirely or keep elements of it for brand recognition and what about our tagline which everyone is tired of but we spent years building it into peoples heads so do we just get rid of it or evolve it somehow also we have these brand gui
# Category: design | Subcategory: brand-identity
#
# ID: pk_08304
# Title: someone lied on their resume and now what do we do
# Content preview: so we just found out that someone we hired like 3 months ago lied on their resume about having a degree. they dont have a bachelors degree which they said they did and we just found out because someone from their actual college called to verify and mentioned they only had an associates or something. honestly i dont even know if this is something we can fire them for?? like is lying on a resume grounds for termination?? i feel like it should be but ive been wrong about HR stuff before. also what if they are actually really good at their job?? like the degree doesnt matter if theyre doing good work right?? but also my boss is like really mad about it and wants to fire them immediately. also what if they sue us for wrongful termination or something?? i really dont know. also this person is like super nice and everyone likes them and they have been working really hard so its kind of sad. also they have been here for 3 months so they might have made some work friends by now. also what do we do about the job offer we made them?? do we take it back?? thats so awkward. also should we tell other people in the company or is that a privacy thing?? i know we cant tell people why they got fired
# Category: hr | Subcategory: hiring-issues
#
# ID: pk_10630
# Title: is it normal to feel lost all the time in grad school
# Content preview: so this isnt really a specific question about research but i guess i just need to vent or get some perspective because i started my PhD like a semester ago and i feel like i dont know what im doing 90 percent of the time and everyone around me seems to know exactly what theyre doing and im just like quietly panicking all the time and pretending everything is fine so basically my advisor gives me these assignments like read these 20 papers and come up with a research proposal and im like okay sure sounds doable but then i spend like 2 weeks reading and i still dont have any good ideas and i feel like i should have ideas by now because isnt that what a PhD is supposed to be about like coming up with new knowledge and ideas and also i dont really understand what my committee is for and when im supposed to meet with them and my advisor seems really busy so i feel bad taking up her time but also i dont know what im doing without guidance so its this Catch-22 situation and also i compare myself to other grad students who seem so much more productive and put together and i dont know if theyre just better at faking it than me or if i actually am behind so yeah basically is this normal or a
# Category: education | Subcategory: graduate-school
#
# ID: pk_02527
# Title: training materials for new customer support people
# Content preview: so i just got promoted to team lead and one of my jobs is to create training materials for new customer support hires and honestly im not really sure what to include because ive been doing this job for like two years but i never really thought about like what someone needs to know to do it you know like i just learned by doing and making mistakes and asking questions and now i have to transfer that knowledge into documents and videos and whatever else they use for training so i was thinking maybe i should start with like a general overview of what customer support is and what we do and then move into like specific scenarios and how to handle them and what tools we use and what policies are important and all that but i dont know if thats the right order or if im missing something important also how detailed should i get because some stuff is really complicated and has a lot of exceptions and edge cases and i dont want to overwhelm new people but i also dont want to leave stuff out and then they encounter it for the first time with a real customer and dont know what to do also should the training be all written or should i do videos too because videos take forever to make but probabl
# Category: customer-support | Subcategory: knowledge-base-articles
#
# ID: pk_00960
# Title: need help with catalog writing for our furniture store
# Content preview: my dad owns a furniture store and he wants me to write product descriptions for the catalog which we print and also put on our website and there are like 500 products and i have to do them all myself which is insane because thats like 500 descriptions times like 200 words each or however long theyre supposed to be which is like 100000 words and thats basically a novel and i have to write a novel about furniture in like three weeks which is my deadline and also i have to do my actual job which is like answering customer questions and managing the website and dealing with deliveries and returns so basically i have no time anyway the problem is i dont even know what a good furniture description sounds like because ive never done this before and the old catalog descriptions were written by some marketing company like 10 years ago and they sound super stiff and corporate and not at all like how people actually talk and i think we should update them to sound more modern and relatable but my dad likes the old ones because he says they sound professional so theres that conflict also some of our furniture is imported and some is made locally and i think that matters for the descriptions but
# Category: marketing | Subcategory: catalog-writing

# %% [markdown]
# **Shortest prompts by word count**
#
# The shortest prompts illustrate a critical challenge for the embedding stage: some records contain extremely limited lexical information, such as one-word or near one-word requests. In these cases, semantic meaning is only partially expressed in the content field and is more likely to emerge from the combination of title, category, subcategory, and tags. These examples show why an embedding strategy based on content alone may underperform on a non-trivial subset of the datase
#
# **Longest prompts by word count**
#
# The longest prompts resemble full user problem descriptions rather than compact prompt templates. They contain narrative context, uncertainty, and implicit goals, which provide rich semantic material for dense representations. These cases are likely to benefit strongly from modern sentence-level or text-level embeddings, since the main challenge is not lexical sparsity but preserving topical and functional coherence across a longer sequence

# %%
print("5 PROMPTS WITH PLACEHOLDERS:")
with_ph = df[df["has_placeholders"] == True].head(5)

for _, row in with_ph.iterrows():
    print("\nID:", row["id"])
    print("Title:", row["title"])
    print("Placeholders:", row["placeholders"])
    print("Content:", row["content"][:1000])
# Out:
# 5 PROMPTS WITH PLACEHOLDERS:
#
# ID: pk_00898
# Title: Create Employee Handbook Section
# Placeholders: ['policy_topic']
# Content: Write a professional employee handbook section about {{policy_topic}}. Include an introduction explaining the policy's purpose, specific guidelines employees should follow, examples of acceptable and unacceptable practices, and information about who to contact with questions. Use a warm but professional tone suitable for new hires.
#
# ID: pk_05166
# Title: Vendor Contract Review
# Placeholders: ['vendor_contract_text']
# Content: Review this vendor contract and identify potential risks and unfavorable clauses. Focus on: indemnification provisions, limitation of liability caps, auto-renewal terms, data handling and security obligations, termination convenience clauses, and governing law implications. Provide specific red flags in a numbered list with recommended revisions for each issue identified.
#
# {{vendor_contract_text}}
#
# ID: pk_02982
# Title: Structure lab protocol steps
# Placeholders: ['lab_notes']
# Content: Convert this informal lab notebook entry into a standardized operating protocol format. Include: purpose statement, required materials with quantities, safety precautions, sequential numbered steps with timing for each, expected outcomes, troubleshooting guide for common problems, and waste disposal instructions.
#
# {{lab_notes}}
#
# ID: pk_02960
# Title: Create Interview Questions for Role
# Placeholders: ['job_role', 'focus_area']
# Content: Generate a set of 10 interview questions for a {{job_role}} position, focusing specifically on {{focus_area}}. Include 3 behavioral questions using the STAR method format, 3 situational questions presenting hypothetical workplace scenarios, 2 role-specific technical questions, and 2 questions assessing cultural fit and values alignment. For each question, provide a brief explanation of what the interviewer should listen for in a strong candidate response.
#
# ID: pk_15710
# Title: Automated response personalization
# Placeholders: ['customer_name']
# Content: Good day! We want to make our automated email responses feel more personal by using the customers first name. Could you help me write code or something to insert the name {{customer_name}} into our templates? I am not very technical. Thank you for your time!

# %%
semantic_fields = [
    "title", "content", "category", "subcategory", "tags", "placeholders", "language"
]

metadata_fields = [
    "author_reputation", "version", "fork_count", "likes", "upvotes", "downvotes",
    "views", "uses", "created_at", "has_placeholders", "difficulty", "target_model"
]

print("SEMANTIC FIELDS:")
for c in semantic_fields:
    print("-", c)

print("\n METADATA / RANKING / FILTERING FIELDS:")
for c in metadata_fields:
    print("-", c)
# Out:
# SEMANTIC FIELDS:
# - title
# - content
# - category
# - subcategory
# - tags
# - placeholders
# - language
#
#  METADATA / RANKING / FILTERING FIELDS:
# - author_reputation
# - version
# - fork_count
# - likes
# - upvotes
# - downvotes
# - views
# - uses
# - created_at
# - has_placeholders
# - difficulty
# - target_model

# %% [markdown]
# **Semantic vs metadata fields**
#
# The distinction between semantic fields and metadata fields is well justified by the dataset design. Fields such as content, title, category, subcategory, tags, and placeholders contribute directly to meaning or task intent, whereas engagement-related and behavioral variables such as likes, views, uses, and reputation are better interpreted as ranking or filtering signals. This separation supports a clean architecture in which semantic similarity is modeled independently from popularity or platform performance

# %% [markdown]
# **Final Overwiev**
#
#
# The exploratory analysis highlighted several findings that are directly relevant to the embedding component. First, the corpus is overwhelmingly English-dominant, which supports the adoption of an English-oriented embedding model. Second, the content field emerges as the main semantic carrier, both by dataset definition and by observed text-length patterns, whereas title appears too short and inconsistent to be used as a standalone semantic representation. At the same time, categories, subcategories, and tags may provide useful contextual support, especially for short or underspecified prompts. Finally, engagement-related variables such as likes, upvotes, views, uses, and author reputation should not be incorporated into the semantic embedding itself, since they reflect behavioral or ranking signals rather than prompt meaning. These observations provide a principled basis for designing the embedding input and for keeping semantic representation separate from later ranking and reranking stages

# %% [markdown]
# # **PARTE NUOVA**
# # **Definition and Construction of Embedding Input Configurations**

# %% [markdown]
# Based on the exploratory data analysis, we designed a single enriched textual representation for embedding generation. Since the `content` field contains the actual instruction or task expressed by each prompt, it was treated as the primary semantic component. At the same time, the analysis showed that additional fields such as `category`, `subcategory`, `tags`, and `title` can provide meaningful context about the prompt domain, topic, and intended usage.
#
# To preserve this information while keeping the input compatible with sentence embedding models, each semi-structured prompt record was converted into a natural-language description. This avoids representing the data as a raw sequence of fields and instead provides the model with a coherent textual input.
#
# **The final embedding input** was constructed according to the following template:
#
# ***"The task is: {content}***
#
# ***This prompt belongs to the {category} category and the {subcategory} subcategory.***
#
# ***It is related to {tags}.***
#
# ***The prompt title is "{title}"***
#
# This structure gives priority to the prompt content while integrating the other semantic fields as contextual signals. The objective is to obtain a representation that remains faithful to the original prompt, but is richer and more informative than the content alone, enabling the embedding model to encode both the task and its semantic context.

# %%
import pandas as pd
import re

def clean_text(text):
    if text is None:
        return ""
    if isinstance(text, float) and pd.isna(text):
        return ""
    text = str(text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
def format_tags(tags, max_tags=4):
    cleaned_tags = [clean_text(tag) for tag in tags if clean_text(tag)]
    cleaned_tags = cleaned_tags[:max_tags]

    if len(cleaned_tags) == 0:
        return ""
    elif len(cleaned_tags) == 1:
        return cleaned_tags[0]
    else:
        return ", ".join(cleaned_tags[:-1]) + f", and {cleaned_tags[-1]}"

# %%
for col in ["content", "category", "subcategory", "title"]:
    print(col, (df[col].astype(str).str.strip() == "").sum())

print("empty tag lists:", df["tags"].apply(lambda x: len(x) == 0).sum())
# Out:
# content 0
# category 0
# subcategory 0
# title 0
# empty tag lists: 6

# %%
def build_embedding_text(row):
    tags = format_tags(row["tags"], max_tags=4)

    sentences = [
        f"The task is: {clean_text(row['content'])}.",
        f"This prompt belongs to the {clean_text(row['category'])} category and the {clean_text(row['subcategory'])} subcategory."
    ]

    if tags:
        sentences.append(f"It is related to {tags}.")

    sentences.append(f'The prompt title is "{clean_text(row["title"])}".')

    return " ".join(sentences)


df["embedding_text"] = df.apply(build_embedding_text, axis=1)

# %% [markdown]
# The template was then implemented by creating a new `embedding_text` column. Before doing so, we applied only minimal preprocessing to ensure that the textual fields were consistently formatted.
#
# The main semantic fields (`content`, `category`, `subcategory`, and `title`) were checked and found to be non-empty for all records, while six prompts had no associated tags. Therefore, the tag-related sentence was included only when tags were available.
#
# As a result, each row of the dataset is mapped to a single natural-language input string. This representation preserves the original prompt content while adding the available semantic context in a controlled and consistent way, and it will be used as the shared input for the embedding models evaluated later.

# %% [markdown]
# some example:

# %%
for i in [0, 10, 25, 100, 250]:
    print("ID:", df.loc[i, "id"])
    print(df.loc[i, "embedding_text"])
# Out:
# ID: pk_03138
# The task is: Create a comprehensive brand identity brief document for a new sustainable fashion startup. Include all essential sections: Executive Summary, Brand Purpose and Mission, Target Audience Persona (demographics, psychographics, behaviors), Brand Positioning statement, Brand Personality (with detailed trait descriptions), Competitive Analysis summary, Core Brand Values, Brand Promise, Tone of Voice guidelines (with examples for different scenarios), and Visual Direction overview. Format this as a professional document a design agency would deliver to stakeholders.. This prompt belongs to the brand-identity category and the strategic-brief subcategory. It is related to brand-brief, sustainable-fashion, strategy, and identity. The prompt title is "Complete Brand Identity Brief".
# ID: pk_15071
# The task is: my sales pipleine has too many stages whats the best setup. This prompt belongs to the sales category and the crm-setup subcategory. It is related to pipeline, stages, crm, and best-practices. The prompt title is "pipelne stages".
# ID: pk_10623
# The task is: hi so i recently got a keyboard piano thing for christmas from my aunt and ive never played any instrument before except like recorder in elementary school which doesnt really count and i really want to learn but theres like so much stuff online i dont know where to start do i need to learn to read sheet music right away or can i learn by just like playing by ear first because honestly sheet music looks really complicated with all those lines and notes and my friend who plays guitar said sheet music is different for piano which is confusing also should i get a teacher or is youtube enough because im on a budget and my mom said shell pay for like 6 lessons if i really want them but im not sure if 6 is enough to like get started or if thats a waste of money. This prompt belongs to the education category and the instrument-learning subcategory. It is related to piano, beginner, learning-resources, and music-lessons. The prompt title is "piano basics where do i even start".
# ID: pk_09454
# The task is: What special considerations and qualifications are needed when translating legal documents such as contracts, patents, or court filings? Discuss certification requirements, terminology precision, formatting standards, and the potential consequences of errors in legal translation.. This prompt belongs to the translation category and the legal-documents subcategory. It is related to legal-translation, certification, precision, and requirements. The prompt title is "Legal Document Translation Requirements".
# ID: pk_13470
# The task is: hi i have to write a proposal for a {{client_name}} and i dont really know how to start its for some company that makes widgets i think and they want like a whole solution or something idk i think they might have a budget of like 50k but im not sure and they want it by friday which is impossible but my manager said just get it done so if you could help me like write something that sounds professional but also not too long bc i dont have time to write a novel oh and they mentioned something about implementation and ROI but i dont know what numbers to put there can you just make something up thats realistic? thanks. This prompt belongs to the sales category and the proposal-writing subcategory. It is related to proposal, sales-document, pricing, and client-communication. The prompt title is "need to write proposal like yesterday".

# %% [markdown]
# Before generating the embeddings, we checked the length of the final `embedding_text` representation. This step was necessary because the enriched input combines several fields of the original dataset and although each field is individually manageable, their combination could potentially create input texts that are too long for some embedding models to process fully.
#
# This is important because embedding models have a maximum input length. If a text exceeds this limit, the model may truncate part of the input, meaning that some semantic information could be ignored during embedding generation. For this reason, we analyzed the word length distribution of the enriched representation before moving to the embedding stage.
#
# The objective of this check was to verify whether the enriched inputs remained compact enough and to identify whether additional truncation strategies would be needed.

# %%
df["embedding_text_len_words"] = df["embedding_text"].str.split().str.len()

print("ENRICHED INPUT LENGTH STATS")
print(df[["embedding_text_len_words"]].describe())

print("\n WORD LENGTH PERCENTILES")
print(df["embedding_text_len_words"].quantile([0.90, 0.95, 0.99]))
# Out:
# ENRICHED INPUT LENGTH STATS
#        embedding_text_len_words
# count              20000.000000
# mean                  85.937650
# std                   48.458988
# min                   25.000000
# 25%                   55.000000
# 50%                   76.000000
# 75%                   99.000000
# max                  310.000000
#
#  WORD LENGTH PERCENTILES
# 0.90    162.0
# 0.95    196.0
# 0.99    242.0
# Name: embedding_text_len_words, dtype: float64

# %% [markdown]
# # **Token Length Check with the Baseline Embedding Model**
#
# After checking the word length of the enriched representation, we also evaluated its token length using the tokenizers of the selected embedding models. This step is important because embedding models process tokenized text and have a fixed maximum sequence length. Therefore, even if the enriched inputs appear reasonably short in terms of words, they may still exceed the model-specific token limit.
#
# We selected three embedding models according to the final goal of the project: semantic retrieval over a corpus of prompts. `all-MiniLM-L6-v2` was used as a lightweight and efficient baseline, `BAAI/bge-base-en-v1.5` as a strong retrieval-oriented model with a good quality-to-size ratio, and `intfloat/e5-base-v2` as another retrieval-oriented model specifically designed for query-passage matching.
#
# Since E5 models are trained to distinguish between queries and passages, we used the prefix `passage:` for the prompt representations in the corpus. User queries will later be encoded with the prefix `query:`. For MiniLM and BGE, we used the standard enriched representation without additional prefixes.

# %%
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer

model_name = "sentence-transformers/all-MiniLM-L6-v2"

model = SentenceTransformer(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("Model max sequence length:", model.max_seq_length)

df["embedding_text_tokens_minilm"] = df["embedding_text"].apply(
    lambda x: len(tokenizer.encode(x, add_special_tokens=True))
)

print("TOKEN LENGTH STATS - MiniLM")
print(df[["embedding_text_tokens_minilm"]].describe())

above_limit = (df["embedding_text_tokens_minilm"] > model.max_seq_length).sum()
percentage_above_limit = above_limit / len(df) * 100

print("\nInputs above model limit:", above_limit)
print("Percentage above model limit:", percentage_above_limit)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model max sequence length: 256
# TOKEN LENGTH STATS - MiniLM
#        embedding_text_tokens_minilm
# count                  20000.000000
# mean                     122.805900
# std                       55.425537
# min                       37.000000
# 25%                       84.000000
# 50%                      117.000000
# 75%                      148.000000
# max                      391.000000
#
# Inputs above model limit: 591
# Percentage above model limit: 2.955

# %%
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer

df["embedding_text_e5"] = "passage: " + df["embedding_text"]


def check_token_length(model_name, text_column):
    model = SentenceTransformer(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    safe_name = model_name.split("/")[-1].replace("-", "_").replace(".", "_")
    token_col = f"tokens_{safe_name}"

    df[token_col] = df[text_column].apply(
        lambda x: len(tokenizer.encode(x, add_special_tokens=True))
    )

    above_limit = (df[token_col] > model.max_seq_length).sum()
    percentage_above_limit = above_limit / len(df) * 100

    print("=" * 80)
    print("Model:", model_name)
    print("Model max sequence length:", model.max_seq_length)
    print(df[[token_col]].describe())
    print("\nInputs above model limit:", above_limit)
    print("Percentage above model limit:", percentage_above_limit)

    return token_col

check_token_length(
    "intfloat/e5-base-v2",
    text_column="embedding_text_e5"
)

check_token_length(
    "BAAI/bge-base-en-v1.5",
    text_column="embedding_text"
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/e5-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ================================================================================
# Model: intfloat/e5-base-v2
# Model max sequence length: 512
#        tokens_e5_base_v2
# count       20000.000000
# mean          124.805900
# std            55.425537
# min            39.000000
# 25%            86.000000
# 50%           119.000000
# 75%           150.000000
# max           393.000000
#
# Inputs above model limit: 0
# Percentage above model limit: 0.0
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ================================================================================
# Model: BAAI/bge-base-en-v1.5
# Model max sequence length: 512
#        tokens_bge_base_en_v1_5
# count             20000.000000
# mean                122.805900
# std                  55.425537
# min                  37.000000
# 25%                  84.000000
# 50%                 117.000000
# 75%                 148.000000
# max                 391.000000
#
# Inputs above model limit: 0
# Percentage above model limit: 0.0
# 'tokens_bge_base_en_v1_5'

# %% [markdown]
# The token length check showed that the enriched representation is fully or almost fully compatible with the selected models. The MiniLM baseline has a maximum sequence length of 256 tokens and would truncate 591 inputs, corresponding to 2.955% of the dataset. This makes MiniLM useful as a lightweight baseline, but less suitable as the final embedding model for the enriched representation.
#
# In contrast, BGE and E5 provide better compatibility with the enriched input. BGE was selected as a strong retrieval-oriented alternative from the proposed open-source models, while E5 was selected because its query-passage training format is well aligned with the final semantic search task. E5, with a maximum sequence length of 512 tokens, can process all enriched inputs without truncation. For this reason, the final embedding comparison focuses on BGE and E5, while MiniLM remains a baseline reference.

# %% [markdown]
# **Embedding Generation with the Selected Models**
#
# Based on the token length analysis, we selected MPNet and E5 for the final embedding generation. MPNet was chosen as a strong general-purpose sentence embedding model, while E5 was selected as a retrieval-oriented model designed for query-passage matching.
#
# Both models are applied to the same enriched prompt representation, so that the comparison focuses on the embedding model rather than on different input configurations. For E5, the `passage:` prefix is used for corpus embeddings, consistently with the model input format.

# %%
bge_model_name = "BAAI/bge-base-en-v1.5"

bge_model = SentenceTransformer(bge_model_name)

embeddings_bge = bge_model.encode(
    df["embedding_text"].tolist(),
    batch_size=128,
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
)

print("BGE embeddings shape:", embeddings_bge.shape)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# BGE embeddings shape: (20000, 768)

# %%
df["embedding_text_e5"] = "passage: " + df["embedding_text"]

e5_model_name = "intfloat/e5-base-v2"

e5_model = SentenceTransformer(e5_model_name)

embeddings_e5 = e5_model.encode(
    df["embedding_text_e5"].tolist(),   
    batch_size=128,
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
)

print("E5 embeddings shape:", embeddings_e5.shape)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/e5-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# E5 embeddings shape: (20000, 768)

# %%
np.save("embeddings_bge_enriched.npy", embeddings_bge)
np.save("embeddings_e5_enriched.npy", embeddings_e5)

retrieval_metadata_cols = [
    "id",
    "likes",
    "upvotes",
    "title",
    "content",
    "category",
    "subcategory",
    "tags",
    "difficulty",
    "language",
    "target_model",
    "embedding_text"
]

df[retrieval_metadata_cols].to_csv("retrieval_metadata_enriched.csv", index=False)

# %% [markdown]
# # **CREATING THE VECTOR DATABASE**
# Now that we have embedded the dataset into vectors, we can proceed to build the vectorial database for a fast and efficient retrieval of our contents.
# We have decided to build 2 databases: one with only config A and one with only config B.
#
# We do so as to be able to play around with all possible combinations of data to find the best approach when we will do operations like retrieval through cosine similarity, or retrieval based on metadata.
#
# We will use ChromaDB as our vector database.

# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chromadb in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.5.8)
# Requirement already satisfied: build>=1.0.3 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.4.4)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (2.14.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.46.0)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (2.2.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.41.1)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: packaging>=24.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.26.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.4)
# Requirement already satisfied: requests-oauthlib in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.31.1)
# Requirement already satisfied: sympy in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.0->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.0->chromadb) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from tokenizers>=0.13.2->chromadb) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\claud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\claud\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import chromadb

config_a_bge = np.load("embeddings_bge_enriched.npy")
config_b_e5 = np.load("embeddings_e5_enriched.npy")
metadata = pd.read_csv("retrieval_metadata_enriched.csv")
print(f"Config A: {len(config_a_bge)}")
print(f"Config B: {len(config_b_e5)}")
print(f"CSV rows: {len(metadata)}")
# Out:
# Config A: 20000
# Config B: 20000
# CSV rows: 20000

# %%
chromaDB = chromadb.PersistentClient(path="/content")

# %%
# We create the two (empty) databases

config_a_bge_collection = chromaDB.get_or_create_collection(name="config_a_bge")
config_b_e5_collection = chromaDB.get_or_create_collection(name="config_b_e5")

# %% [markdown]
# **Filling the databases**
#
# Once the two empty databases have been created, we go on to the next part: actually loading the vectors we prepared earlier to the databases. We will create a function that takes care of the vector storage, and we will implement, together with those, metadata which will help us in the later parts (retrieval).

# %%
# This function will help us iterate through each different array of embeddings
# and adding them one by one to the database

def chromadb_database_adder(database, np_array, metadata, batch_size):
    vectors = np_array.tolist()
    total = len(np_array)

    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)

        ids = [str(metadata["id"][i]) for i in range(start, end)]
        embeddings = [vectors[i] for i in range(start, end)]
        documents  = [str(metadata["content"][i]) for i in range(start, end)]
        metadatas = [{
                "title":str(metadata["title"][i]),
                "category":str(metadata["category"][i]),
                "subcategory":str(metadata["subcategory"][i]),
                "tags":str(metadata["tags"][i]),
                "difficulty":str(metadata["difficulty"][i]),
                "likes":int(metadata["likes"][i]),
                "upvotes":int(metadata["upvotes"][i]),
        } for i in range(start, end)]

        database.add(
            ids=ids,
            documents=documents,
            embeddings=embeddings,
            metadatas=metadatas,
        )

# %%
# WE LOAD THE VECTORS INTO THE DATABASES

chromadb_database_adder(config_a_bge_collection, config_a_bge, metadata, 100)
chromadb_database_adder(config_b_e5_collection, config_b_e5, metadata, 100)

# %% [markdown]
# **Sanity checks**
#
# Now that we have built the databases, we can run some quick sanity checks to verify that they are up to standard.

# %%
# Verify that vectors can be retrieved
config_a_bge_collection.get(ids="pk_03138", include=["embeddings"])
config_b_e5_collection.get(ids="pk_03138")

# Check the length of the databases. Should be equal to the embedded vectors
print("Config A count:", config_a_bge_collection.count())
print("Config B count:", config_b_e5_collection.count())
# Out:
# Config A count: 20000
# Config B count: 20000

# %% [markdown]
# **Testing the queries**

# %%
from sentence_transformers import SentenceTransformer

e5_model_name = "intfloat/e5-base-v2"
e5_model = SentenceTransformer(e5_model_name)

query_text = "Create a comprehensive brand identity brief document for a new sustainable fashion startup. Include all essential sections: Executive Summary, Brand Purpose and Mission, Target Audience Persona (demographics, psychographics, behaviors), Brand Positioning statement, Brand Personality (with detailed trait descriptions), Competitive Analysis summary, Core Brand Values, Brand Promise, Tone of Voice guidelines (with examples for different scenarios), and Visual Direction overview. Format this as a professional document a design agency would deliver to stakeholders."
query_embedding = e5_model.encode([query_text]).tolist()

config_b_e5_collection.query(
    query_embeddings=query_embedding,
    n_results=3
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/e5-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# {'ids': [['pk_03138', 'pk_15035', 'pk_05234']],
#  'embeddings': None,
#  'documents': [['Create a comprehensive brand identity brief document for a new sustainable fashion startup. Include all essential sections: Executive Summary, Brand Purpose and Mission, Target Audience Persona (demographics, psychographics, behaviors), Brand Positioning statement, Brand Personality (with detailed trait descriptions), Competitive Analysis summary, Core Brand Values, Brand Promise, Tone of Voice guidelines (with examples for different scenarios), and Visual Direction overview. Format this as a professional document a design agency would deliver to stakeholders.',
#    'Create comprehensive brand guidelines for a sustainable fashion startup. The guidelines must include: 1) Brand mission and personality statement, 2) Color palette with specific hex codes, CMYK, and Pantone values, 3) Typography system with primary and secondary fonts, 4) Logo usage rules (clear space, minimum size, incorrect uses), 5) Photography and imagery style guide, 6) Voice and tone examples, 7) Common brand mistakes to avoid. Format the output as a structured document with clear sections and practical examples.',
#    "Create comprehensive brand voice guidelines for a sustainable fashion startup targeting millennials and Gen Z. Include: 1) Brand personality traits (5 adjectives with descriptions), 2) Tone variations for different contexts (casual, professional, emotional), 3) Vocabulary do's and don'ts (20 words each), 4) Example phrases for common scenarios (product descriptions, customer service, social media), 5) Messaging pillars with sample taglines. Format as an elegant PDF-ready document with clear sections and visual hierarchy."]],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'likes': 478,
#     'difficulty': 'expert',
#     'tags': "['brand-brief', 'sustainable-fashion', 'strategy', 'identity']",
#     'subcategory': 'strategic-brief',
#     'title': 'Complete Brand Identity Brief',
#     'category': 'brand-identity',
#     'upvotes': 277},
#    {'title': 'Develop brand guidelines document',
#     'likes': 271,
#     'subcategory': 'brand-identity',
#     'tags': "['brand-guidelines', 'sustainable-fashion', 'style-guide', 'documentation', 'comprehensive']",
#     'difficulty': 'expert',
#     'upvotes': 271,
#     'category': 'design'},
#    {'upvotes': 9,
#     'category': 'marketing',
#     'tags': "['brand-voice', 'guidelines', 'style-guide', 'sustainable-fashion', 'millennials']",
#     'difficulty': 'advanced',
#     'likes': 10,
#     'title': 'Create brand voice guidelines document',
#     'subcategory': 'branding'}]],
#  'distances': [[0.07371219992637634,
#    0.17235785722732544,
#    0.19290046393871307]]}

# %% [markdown]
# # STEP 3: Cosine Similarity Retrieval
#
# **Recap and explanation of this step:**
# After having completed step 1 and 2 by embedding all 20,000 prompts into vectors and storing them in a ChromaDB vector database, we are ready to handle the query part.
#
# This section handles the query side of the user, and given a natural language search query we will:
# 1. Embed the query using the **same model** used in Step 1 (`all-MiniLM-L6-v2`)
# 2. Search ChromaDB using **cosine similarity** to find the closest matching prompts
# 3. Return ranked results (that will later be passed to the reranker in Step 4)
#
#
# We run this on **both Config A** (content only) and **Config B** (title + category + subcategory + tags + content) so the reranker team can compare both.

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip install -q sentence-transformers chromadb
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\claud\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Load the embedding models
#
# We must use the **exact same model** that Step 1 used to embed the prompts.
# Clearly, this is because if we used a different model, the query vector would live in a different "space" and cosine similarity would be meaningless.

# %%
from sentence_transformers import SentenceTransformer


bge_model = SentenceTransformer("BAAI/bge-base-en-v1.5")
e5_model = SentenceTransformer("intfloat/e5-base-v2")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: intfloat/e5-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ## 3. Connect to ChromaDB
#
# Step 2 created two collections in ChromaDB (`config_a_bge`, `config_b_e5`). We connect to the database here.

# %%
import chromadb

# ChromaDB
chromaDB = chromadb.PersistentClient(path="/content")
config_a_chromadb = chromaDB.get_collection(name="config_a_bge")
config_b_chromadb = chromaDB.get_collection(name="config_b_e5")

print(f"ChromaDB Config A Loading Check: {config_a_chromadb.count()} prompts")
print(f"ChromaDB Config B Loading Check: {config_b_chromadb.count()} prompts")
# Out:
# ChromaDB Config A Loading Check: 20000 prompts
# ChromaDB Config B Loading Check: 20000 prompts

# %% [markdown]
# ## 4. Retrieval function
#
# We implement a retrieval function for ChromaDB that:
# - Takes a natural language query and converts it into a vector
# - Searches the vector database using cosine similarity
# - Returns results sorted from most to least relevant, each with a similarity score and full metadata (including `likes`, `upvotes`, `difficulty` for the reranker)

# %%
import numpy as np
import time

def retrieve_chromadb(query: str, collection, embedding_model, top_k: int = 20, query_prefix=""):
    query_vector = embedding_model.encode(
        query_prefix + query,
        convert_to_numpy=True
    ).tolist()

    # Searching ChromaDB
    start = time.time()
    results = collection.query(
        query_embeddings=[query_vector],
        n_results=top_k,
        include=["documents", "metadatas", "distances"]
    )
    latency = time.time() - start

    # ChromaDB returns lists-of-lists (one per query), so we take index [0]
    ids       = results["ids"][0]
    documents = results["documents"][0]
    metadatas = results["metadatas"][0]
    distances = results["distances"][0]

    # ChromaDB distance = 1 - cosine_similarity, so we convert back
    formatted = []
    for rank, (pid, doc, meta, dist) in enumerate(zip(ids, documents, metadatas, distances), start=1):
        formatted.append({
            "rank":rank,
            "id":pid,
            "similarity":round(1 - dist, 4),
            "distance":round(dist, 4),
            "title":meta.get("title", ""),
            "category":meta.get("category", ""),
            "subcategory":meta.get("subcategory", ""),
            "tags":meta.get("tags", ""),
            "difficulty":meta.get("difficulty", ""),
            "likes":meta.get("likes", 0),
            "upvotes":meta.get("upvotes", 0),
            "content":doc,
        })

    return formatted, latency


def print_results(results, query, label):
    print(f"\n{'='*70}")
    print(f"Query: \"{query}\"")
    print(f"{'='*70}")
    for r in results:
        print(f"\n  #{r['rank']}  [{r['id']}]  similarity={r['similarity']}")
        print(f"  Title      : {r['title']}")
        print(f"  Category   : {r['category']} > {r['subcategory']}")
        print(f"  Tags       : {r['tags']}")
        print(f"  Difficulty : {r['difficulty']} | Likes: {r['likes']} | Upvotes: {r['upvotes']}")
        print(f"  Content    : {r['content'][:180]}...")
        print(f"  {'-'*66}")

# %% [markdown]
# ## 5. Running a search
#
# Change `QUERY` to whatever you want to search for.

# %%
QUERY = "help me write a professional email to a client"
TOP_K = 20

results_a, _ = retrieve_chromadb(QUERY, config_a_chromadb, bge_model, top_k=TOP_K)
results_b, _ = retrieve_chromadb(QUERY, config_b_chromadb, e5_model, top_k=TOP_K)

print_results(results_a[:5], QUERY, "Config A (content only)")
print_results(results_b[:5], QUERY, "Config B (enriched: title + category + tags + content)")
# Out:
# ======================================================================
# Query: "help me write a professional email to a client"
# ======================================================================
#
#   #1  [pk_00021]  similarity=0.5297
#   Title      : A small request if you don't mind - new to sales and feeling a bit lost
#   Category   : sales > cold-outreach
#   Tags       : ['cold email', 'templates', 'beginner', 'office supplies']
#   Difficulty : beginner | Likes: 3 | Upvotes: 0
#   Content    : Good day to you! I hope this message finds you well and that you are having a lovely week so far. My name is Gerald and I recently started a new job in sales for a small company th...
#   ------------------------------------------------------------------
#
#   #2  [pk_14385]  similarity=0.5249
#   Title      : Sorry to take up your time
#   Category   : marketing > email-campaigns
#   Tags       : ['b2b-email', 'plumbing', 'business-outreach']
#   Difficulty : intermediate | Likes: 315 | Upvotes: 258
#   Content    : Good morning! I am Eugene and I own a plumbing company. I need to write some emails to potential business clients like offices and restaurants. I want to seem professional but also...
#   ------------------------------------------------------------------
#
#   #3  [pk_19817]  similarity=0.5203
#   Title      : A small favour if you dont mind dear
#   Category   : sales > cold-outreach
#   Tags       : ['cold-email', 'linkedin', 'polite', 'office-supplies']
#   Difficulty : beginner | Likes: 8 | Upvotes: 8
#   Content    : Hello there! I hope you are having a wonderful day. My name is Harold and I have been working in sales for about 25 years now at a small company that sells office supplies. I was w...
#   ------------------------------------------------------------------
#
#   #4  [pk_07901]  similarity=0.5191
#   Title      : Draft client email response
#   Category   : productivity > email-management
#   Tags       : ['email-writing', 'client-communication', 'professional-tone', 'apology-email', 'customer-relations']
#   Difficulty : beginner | Likes: 373 | Upvotes: 269
#   Content    : Act as a professional email writer. Draft a response to the following client inquiry about a delayed project delivery. The tone should be apologetic but confident, acknowledge thei...
#   ------------------------------------------------------------------
#
#   #5  [pk_12525]  similarity=0.5161
#   Title      : Write professional email templates
#   Category   : productivity > email-management
#   Tags       : ['email', 'templates', 'professional', 'communication', 'outreach']
#   Difficulty : beginner | Likes: 86 | Upvotes: 65
#   Content    : Write {{number}} professional email templates for {{use_case}} in a {{tone}} tone. Include templates for: initial outreach, follow-up (day 3 and day 7 variants), scheduling request...
#   ------------------------------------------------------------------
#
# ======================================================================
# Query: "help me write a professional email to a client"
# ======================================================================
#
#   #1  [pk_05873]  similarity=0.7304
#   Title      : Please help me write something formal
#   Category   : customer-support > escalation-scripts
#   Tags       : ['escalation-email', 'management', 'formal', 'supervisor']
#   Difficulty : intermediate | Likes: 74 | Upvotes: 74
#   Content    : Good evening, I hope I am not disturbing you. I am a supervisor in customer support and I need to write an email to escalate a difficult situation to upper management. I want to be...
#   ------------------------------------------------------------------
#
#   #2  [pk_08029]  similarity=0.7298
#   Title      : Draft Professional Email Response
#   Category   : productivity > email-management
#   Tags       : ['email', 'customer-service', 'communication', 'professional', 'templates']
#   Difficulty : intermediate | Likes: 62 | Upvotes: 62
#   Content    : Write a professional email response in {{tone}} tone for {{company_name}} addressing a customer complaint about a delayed shipment. Acknowledge the issue, apologize sincerely, prov...
#   ------------------------------------------------------------------
#
#   #3  [pk_12646]  similarity=0.7268
#   Title      : Professional Email Response Generator
#   Category   : email-management > drafting
#   Tags       : ['email-writing', 'professional-communication', 'business-correspondence', 'tone-matching']
#   Difficulty : intermediate | Likes: 264 | Upvotes: 111
#   Content    : You are an executive assistant specializing in professional communication. Draft a response email for the following scenario: {{email_type}} in the {{industry}} sector. The tone sh...
#   ------------------------------------------------------------------
#
#   #4  [pk_07901]  similarity=0.7266
#   Title      : Draft client email response
#   Category   : productivity > email-management
#   Tags       : ['email-writing', 'client-communication', 'professional-tone', 'apology-email', 'customer-relations']
#   Difficulty : beginner | Likes: 373 | Upvotes: 269
#   Content    : Act as a professional email writer. Draft a response to the following client inquiry about a delayed project delivery. The tone should be apologetic but confident, acknowledge thei...
#   ------------------------------------------------------------------
#
#   #5  [pk_12525]  similarity=0.7208
#   Title      : Write professional email templates
#   Category   : productivity > email-management
#   Tags       : ['email', 'templates', 'professional', 'communication', 'outreach']
#   Difficulty : beginner | Likes: 86 | Upvotes: 65
#   Content    : Write {{number}} professional email templates for {{use_case}} in a {{tone}} tone. Include templates for: initial outreach, follow-up (day 3 and day 7 variants), scheduling request...
#   ------------------------------------------------------------------

# %% [markdown]
# ## 6. A/B comparison across multiple queries
#
# We test several queries and compare whether Config A or Config B returns better top results.
# This is the A/B comparison the challenge evaluation requires.

# %%
test_queries = [
    "write Python code to scrape a website",
    "summarize a legal contract",
    "create a marketing post for Instagram",
    "explain machine learning to a beginner",
    "generate a cold outreach email for sales",
]

print("Running A/B comparison across test queries...\n")

for query in test_queries:
    res_a, _ = retrieve_chromadb(query, config_a_chromadb, bge_model, top_k=5)
    res_b, _ = retrieve_chromadb(query, config_b_chromadb, e5_model, top_k=5)

    ids_a = [r["id"] for r in res_a]
    ids_b = [r["id"] for r in res_b]
    overlap = len(set(ids_a) & set(ids_b))

    print(f"\nQUERY: \"{query}\"")
    for i in range(5):
        match = "✓" if res_a[i]["id"] == res_b[i]["id"] else "✗"
        print(f"  #{i+1} {match}  A: [{res_a[i]['id']}] sim={res_a[i]['similarity']} | {res_a[i]['title'][:40]}")
        print(f"       B: [{res_b[i]['id']}] sim={res_b[i]['similarity']} | {res_b[i]['title'][:40]}")
    print(f"  → Shared prompts in top 5: {overlap}/5")
# Out:
# Running A/B comparison across test queries...
#
#
# QUERY: "write Python code to scrape a website"
#   #1 ✗  A: [pk_07903] sim=0.2662 | pyhton scrip for data viz
#        B: [pk_05798] sim=0.6762 | Clean and Merge Multiple Datasets
#   #2 ✗  A: [pk_12201] sim=0.254 | pyhton script for data
#        B: [pk_19610] sim=0.6706 | pyhton script for netwerk monitering
#   #3 ✗  A: [pk_10393] sim=0.2502 | code plz
#        B: [pk_15185] sim=0.6669 | custmer churn data
#   #4 ✗  A: [pk_05798] sim=0.2478 | Clean and Merge Multiple Datasets
#        B: [pk_18916] sim=0.6657 | pyhton scrip for data
#   #5 ✗  A: [pk_02369] sim=0.2403 | Data Cleaning Code Template
#        B: [pk_07903] sim=0.662 | pyhton scrip for data viz
#   → Shared prompts in top 5: 2/5
#
# QUERY: "summarize a legal contract"
#   #1 ✓  A: [pk_17110] sim=0.6719 | Contract Summary Generator
#        B: [pk_17110] sim=0.7837 | Contract Summary Generator
#   #2 ✓  A: [pk_04414] sim=0.5863 | Contract Summary Extraction
#        B: [pk_04414] sim=0.7591 | Contract Summary Extraction
#   #3 ✓  A: [pk_14742] sim=0.5747 | Create contract summary template
#        B: [pk_14742] sim=0.7528 | Create contract summary template
#   #4 ✓  A: [pk_04029] sim=0.5307 | Summarize Contract Clause
#        B: [pk_04029] sim=0.7384 | Summarize Contract Clause
#   #5 ✗  A: [pk_00768] sim=0.5254 | Translate Legal Language
#        B: [pk_11643] sim=0.7264 | contract help
#   → Shared prompts in top 5: 4/5
#
# QUERY: "create a marketing post for Instagram"
#   #1 ✗  A: [pk_08784] sim=0.5282 | Generate social media product posts
#        B: [pk_11941] sim=0.7722 | ig post
#   #2 ✗  A: [pk_11941] sim=0.4839 | ig post
#        B: [pk_16820] sim=0.7462 | ig post
#   #3 ✗  A: [pk_02029] sim=0.4757 | Instagram Growth Strategy Questions
#        B: [pk_01903] sim=0.7422 | instagram post
#   #4 ✗  A: [pk_04351] sim=0.4578 | A question about advertising my restaura
#        B: [pk_08784] sim=0.7404 | Generate social media product posts
#   #5 ✗  A: [pk_10117] sim=0.456 | need help with my instagram thing
#        B: [pk_06986] sim=0.7388 | SOCIAL MEDIA POSTS FAST
#   → Shared prompts in top 5: 2/5
#
# QUERY: "explain machine learning to a beginner"
#   #1 ✗  A: [pk_03208] sim=0.6046 | machine learning thing for beginners que
#        B: [pk_17974] sim=0.7383 | ml explaind simpl
#   #2 ✗  A: [pk_16479] sim=0.5557 | what is machine learning and how do i st
#        B: [pk_09085] sim=0.736 | ml beginner
#   #3 ✗  A: [pk_01948] sim=0.551 | trying to build a model but idk what im
#        B: [pk_03208] sim=0.7295 | machine learning thing for beginners que
#   #4 ✗  A: [pk_03191] sim=0.5439 | what is machine learning and how do i st
#        B: [pk_18843] sim=0.7205 | Explain Neural Network to Beginners
#   #5 ✗  A: [pk_17974] sim=0.5297 | ml explaind simpl
#        B: [pk_15923] sim=0.7133 | regression easy
#   → Shared prompts in top 5: 2/5
#
# QUERY: "generate a cold outreach email for sales"
#   #1 ✗  A: [pk_06291] sim=0.6141 | Cold Email Template Generator
#        B: [pk_14706] sim=0.8367 | Cold Outreach Email Template
#   #2 ✗  A: [pk_12488] sim=0.6024 | Generate Cold Outreach Email Sequence
#        B: [pk_04958] sim=0.8362 | Cold outreach email template
#   #3 ✗  A: [pk_03039] sim=0.6015 | Generate cold email sequence
#        B: [pk_13911] sim=0.8361 | Cold outreach email for SaaS product
#   #4 ✗  A: [pk_03200] sim=0.5857 | Cold Email Sequence Generator
#        B: [pk_06291] sim=0.8358 | Cold Email Template Generator
#   #5 ✗  A: [pk_12163] sim=0.5753 | Cold outreach email template
#        B: [pk_07611] sim=0.8343 | Cold Outreach Email Template
#   → Shared prompts in top 5: 1/5

# %% [markdown]
# ## 7. Evaluate retrieval quality — Precision@K and MRR
#
# To measure quality we picked a small set of queries where we manually mark which results are truly relevant.
#
# - **Precision@K**: of the top K results, what fraction are actually relevant?
# - **MRR (Mean Reciprocal Rank)**: on average, how high up does the first relevant result appear? (1.0 = always #1, 0.5 = first relevant is at #2, etc.)

# %%
GROUND_TRUTH = {
    "create a social media marketing campaign": [
        "pk_02364",  # Social media visual campaign
        "pk_00017",  # Social Media Content Calendar
        "pk_14568",  # Social Media Content Calendar Generator
        "pk_16478",  # Viral Social Media Post Formulas
        "pk_01267",  # Create Hashtag Strategy Plan
    ],
    "write a response to a negative customer review": [
        "pk_06217",  # Negative Review Response Templates (ticket-responses)
        "pk_04336",  # Negative Review Response Templates (ticket-responses)
        "pk_19170",  # Negative Review Response Templates (marketing)
        "pk_11972",  # Create negative review response strategy
        "pk_07091",  # Complaint Acknowledgment Response
    ],
    "write a SQL query to analyze database data": [
        "pk_19178",  # SQL Customer Segmentation
        "pk_18782",  # SQL Query for Monthly Revenue
        "pk_00054",  # Design E-commerce Database
        "pk_00632",  # Optimize slow database queries
        "pk_17577",  # Optimize Slow Database Queries
    ],
}


def precision_at_k(results, relevant_ids, k):
    top_k_ids = [r["id"] for r in results[:k]]
    hits = sum(1 for pid in top_k_ids if pid in relevant_ids)
    return hits / k


def reciprocal_rank(results, relevant_ids):
    for i, r in enumerate(results, start=1):
        if r["id"] in relevant_ids:
            return 1.0 / i
    return 0.0

def evaluate(collection, ground_truth, embedding_model, top_k=10, label=""):
    p_scores, rr_scores = [], []
    for query, relevant_ids in ground_truth.items():
        if not relevant_ids:
            continue
        results, _ = retrieve_chromadb(query, collection, embedding_model, top_k=top_k)
        p = precision_at_k(results, set(relevant_ids), k=top_k)
        rr = reciprocal_rank(results, set(relevant_ids))
        p_scores.append(p)
        rr_scores.append(rr)
        print(f"  Query: '{query[:50]}' | P@{top_k}={p:.2f} | RR={rr:.2f}")

    if p_scores:
        print(f"\n  Config {label} — Mean P@{top_k}: {np.mean(p_scores):.3f} | MRR: {np.mean(rr_scores):.3f}")
    else:
        print(f"  Config {label} — No ground truth yet. Add relevant IDs to GROUND_TRUTH above.")


print("=== Config A ===")
evaluate(config_a_chromadb, GROUND_TRUTH, bge_model, top_k=10, label="A")

print("\n=== Config B ===")
evaluate(config_b_chromadb, GROUND_TRUTH, e5_model, top_k=10, label="B")
def NDCG (results, relevant_ids, k):   
    def dcg_at_k(results, relevant_ids, k):
        dcg = 0.0
        for i in range(k):
            if results[i]["id"] in relevant_ids:
                dcg += 1 / np.log2(i + 2)  # i+2 because rank starts at 1
        return dcg
    dcg = dcg_at_k(results, relevant_ids, k)
    def idcg_at_k(relevant_ids, k):
        ideal_dcg = sum(1 / np.log2(i + 2) for i in range(min(len(relevant_ids), k)))
        return ideal_dcg
    idcg = idcg_at_k(relevant_ids, k)
    return dcg / idcg if idcg > 0 else 0.0
# Out:
# === Config A ===
#   Query: 'create a social media marketing campaign' | P@10=0.10 | RR=0.20
#   Query: 'write a response to a negative customer review' | P@10=0.30 | RR=0.33
#   Query: 'write a SQL query to analyze database data' | P@10=0.00 | RR=0.00
#
#   Config A — Mean P@10: 0.133 | MRR: 0.178
#
# === Config B ===
#   Query: 'create a social media marketing campaign' | P@10=0.10 | RR=0.50
#   Query: 'write a response to a negative customer review' | P@10=0.20 | RR=1.00
#   Query: 'write a SQL query to analyze database data' | P@10=0.00 | RR=0.00
#
#   Config B — Mean P@10: 0.100 | MRR: 0.500

# %% [markdown]
# ## 8. Export results for Step 4 (the reranker)
#
# We package the top candidates for a given query into a clean format
# that the reranker team (Step 4) can directly consume.
# Each result includes `likes`, `upvotes`, and `difficulty` so the reranker can use them for metadata-aware scoring.

# %%
import json

def get_candidates_for_reranker(query: str, top_k: int = 50):
    results_a, _ = retrieve_chromadb(query, config_a_chromadb, bge_model, top_k=top_k)
    results_b, _ = retrieve_chromadb(query, config_b_chromadb, e5_model, top_k=top_k)

    output = {
        "query": query,
        "top_k": top_k,
        "config_a_candidates": results_a,
        "config_b_candidates": results_b,
    }
    return output

QUERY = input("Enter your search query: ").strip()

if not QUERY:
    QUERY = "help me write a professional email to a client"

candidates = get_candidates_for_reranker(QUERY, top_k=50)

with open("/content/candidates_for_reranker.json", "w") as f:
    json.dump(candidates, f, indent=2)

print(f"Exported {len(candidates['config_a_candidates'])} candidates (Config A)")
print(f"Exported {len(candidates['config_b_candidates'])} candidates (Config B)")
print("Saved to: /content/candidates_for_reranker.json")
# Out:
# Exported 50 candidates (Config A)
# Exported 50 candidates (Config B)
# Saved to: /content/candidates_for_reranker.json

# %% [markdown]
# ## RERANKER (PART 4)

# %% [markdown]
# Before building the reranker, let's do a sanity check

# %%
print(config_a_bge.shape)
print(config_b_e5.shape)
print(metadata.shape)
# Out:
# (20000, 768)
# (20000, 768)
# (20000, 12)

# %%
print("Chroma A:", config_a_chromadb.count())
print("Chroma B:", config_b_chromadb.count())
# Out:
# Chroma A: 20000
# Chroma B: 20000

# %%
candidates.keys()
# Out:
# dict_keys(['query', 'top_k', 'config_a_candidates', 'config_b_candidates'])

# %%
#print example candidate
print("\nExample candidate from Config A:")
print(candidates["config_a_candidates"][49])
print("\nExample candidate from Config B:")
print(candidates["config_b_candidates"][49])
# Out:
# Example candidate from Config A:
# {'rank': 50, 'id': 'pk_02240', 'similarity': 0.4395, 'distance': 0.5605, 'title': 'thank you email template', 'category': 'marketing', 'subcategory': 'email-marketing', 'tags': "['email-template', 'thank-you', 'review-request', 'ecommerce']", 'difficulty': 'beginner', 'likes': 419, 'upvotes': 288, 'content': 'hi i need a thank you email template for my online store basically after someone buys something i want to send them a thank you email and maybe ask for a review which i heard is important for social proof or whatever so if you could write me like a template that would be great that i can just copy and paste for each order also i want it to sound friendly and not too corporate or salesy because im a small handmade business and i want people to feel like theyre buying from a real person not some huge company also should i send it right away or wait a few days also i want to include some kind of discount code for their next purchase to get them to come back but i dont know if thats too pushy or if thats normal also my email platform is mailchimp if that matters'}
#
# Example candidate from Config B:
# {'rank': 50, 'id': 'pk_00021', 'similarity': 0.681, 'distance': 0.319, 'title': "A small request if you don't mind - new to sales and feeling a bit lost", 'category': 'sales', 'subcategory': 'cold-outreach', 'tags': "['cold email', 'templates', 'beginner', 'office supplies']", 'difficulty': 'beginner', 'likes': 3, 'upvotes': 0, 'content': 'Good day to you! I hope this message finds you well and that you are having a lovely week so far. My name is Gerald and I recently started a new job in sales for a small company that sells office supplies. I must admit I am not very familiar with how to write good cold emails to potential customers and I was wondering if you might be so kind as to help me with some templates or examples? I would really appreciate any guidance you could offer. Please forgive me if my request is too basic or if I am not explaining myself clearly. Thank you so much in advance for your time and patience. Warmest regards, Gerald'}

# %% [markdown]
# After performing vector retrieval we need to fine our search by performing a reranking over the best results that we got so that they can be ordered over certain criterias

# %%
#as a model we will choose cross-encoder/ms-marco-MiniLM-L-6-v2, which is fine-tuned for relevance ranking tasks and should perform well in distinguishing subtle differences in prompt relevance.
from sentence_transformers import SentenceTransformer, util, CrossEncoder
RERANKER_MODEL_NAME = "cross-encoder/ms-marco-MiniLM-L-6-v2"
reranker_model = CrossEncoder(RERANKER_MODEL_NAME)
print(f"Reranker model loaded: {RERANKER_MODEL_NAME}")
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Reranker model loaded: cross-encoder/ms-marco-MiniLM-L-6-v2

# %% [markdown]
# In order to improve the reranker and make sure that it might perform also when the prompt is vague or unclear we want to incorporate in a structured textual representation also other attributes, like title, category and tags, so that it would improve our retrieval. This ensures also a coherence with "Config B" where said attributes where already taken into account for embedding.

# %% [markdown]
# Now time for the reranker function, that takes the "rough" candidates resulting from the vector search and reorders them using a stronger model, returning only the top k results.

# %%
def rerank_candidates(query, candidates, top_k=10):
    query = query.strip() #remove leading/trailing whitespace
    candidate_texts = [candidate.get("content") for candidate in candidates] #retrieve the text representation for each candidate
    pairs = [[query, ct] for ct in candidate_texts] #prepare the input pairs for the cross-encoder (query + candidate text)
    scores = reranker_model.predict(pairs) #cross-encoder returns relevance scores for each pair (higher = more relevant)
    reranked = [{"candidate": c, "rerank_score": float(s)} for c, s in zip(candidates, scores)] #attach scores to candidates
    return sorted(reranked, key=lambda x: x["rerank_score"], reverse=True)[:top_k] #sort candidates by rerank_score and return top_k

# %% [markdown]
# Testing on candidates from Config A:

# %%
reranked_a = rerank_candidates(QUERY, candidates["config_a_candidates"], top_k=5)

print("\nTop 5 reranked candidates from Config A:")
for i, item in enumerate(reranked_a, start=1):
    c = item["candidate"]
    score = item["rerank_score"]
    print(f"\n {i}  ID: {c['id']}  Rerank Score: {score:.4f}")
    print(f" Title: {c['title']}")
    print(f"content:{c['content']}")
# Out:
# Top 5 reranked candidates from Config A:
#
#  1  ID: pk_07901  Rerank Score: 5.6294
#  Title: Draft client email response
# content:Act as a professional email writer. Draft a response to the following client inquiry about a delayed project delivery. The tone should be apologetic but confident, acknowledge their frustration, explain the reason for delay (resource constraints), outline the revised timeline with specific dates, and offer a 15% discount on the next phase as compensation. Keep the email under 200 words and end with a clear call to action to schedule a call to discuss further. Output the email in plain text format ready to send.
#
#  2  ID: pk_01223  Rerank Score: 4.7215
#  Title: Email Template for {{purpose}}
# content:Write a professional email template for {{purpose}} communication. The tone should be {{tone}}, and it should be suitable for {{audience}}. Include subject line suggestions, opening greeting variations, body structure, and closing options. Make it adaptable by highlighting areas that need customization.
#
#  3  ID: pk_00096  Rerank Score: 4.6672
#  Title: Cold outreach email template
# content:Write a cold outreach email for a potential client at {{company_name}} to introduce our {{product_name}}. The tone should be {{tone}} — professional yet approachable, highlighting value without being pushy. Include a clear call-to-action and keep it under 150 words.
#
#  4  ID: pk_08029  Rerank Score: 3.9436
#  Title: Draft Professional Email Response
# content:Write a professional email response in {{tone}} tone for {{company_name}} addressing a customer complaint about a delayed shipment. Acknowledge the issue, apologize sincerely, provide a revised delivery timeline, and offer a 15% discount on their next order as compensation.
#
#  5  ID: pk_14385  Rerank Score: 3.8441
#  Title: Sorry to take up your time
# content:Good morning! I am Eugene and I own a plumbing company. I need to write some emails to potential business clients like offices and restaurants. I want to seem professional but also friendly you know? Not too stiff. Could you help me with some email templates? I would need something for first contact and maybe a follow up email too. If its not too much trouble. Thank you so much, Eugene

# %% [markdown]
# Now on Candidates from B

# %%
# And now on the candidates from Config B
reranked_b = rerank_candidates(QUERY, candidates["config_b_candidates"], top_k=5)


print("\nTop 5 reranked candidates from Config B:")
for i, item in enumerate(reranked_b, start=1):
    c = item["candidate"]
    score = item["rerank_score"]
    print(f"\n {i}  ID: {c['id']}  Rerank Score: {score:.4f}")
    print(f" Title: {c['title']}")
    print(f"content:{c['content']}")
# Out:
# Top 5 reranked candidates from Config B:
#
#  1  ID: pk_07901  Rerank Score: 5.6294
#  Title: Draft client email response
# content:Act as a professional email writer. Draft a response to the following client inquiry about a delayed project delivery. The tone should be apologetic but confident, acknowledge their frustration, explain the reason for delay (resource constraints), outline the revised timeline with specific dates, and offer a 15% discount on the next phase as compensation. Keep the email under 200 words and end with a clear call to action to schedule a call to discuss further. Output the email in plain text format ready to send.
#
#  2  ID: pk_16889  Rerank Score: 5.0573
#  Title: Draft ticket response for printer issue
# content:Write a professional email response for a customer whose order arrived damaged. Acknowledge their frustration, apologize for the inconvenience, and explain the replacement process. Keep the tone empathetic but efficient.
#
#  3  ID: pk_00072  Rerank Score: 4.9280
#  Title: Draft Professional Ticket Response
# content:Write a professional email response to a customer whose order arrived damaged. Acknowledge their frustration, apologize sincerely, and outline the steps to send a replacement immediately.
#
#  4  ID: pk_18800  Rerank Score: 4.8926
#  Title: Draft Support Ticket Response
# content:Write a professional email response to a customer whose order was delayed. Acknowledge their frustration, apologize sincerely, provide a revised delivery estimate with a specific date, and include a 20% discount code for their next purchase as compensation.
#
#  5  ID: pk_01223  Rerank Score: 4.7215
#  Title: Email Template for {{purpose}}
# content:Write a professional email template for {{purpose}} communication. The tone should be {{tone}}, and it should be suitable for {{audience}}. Include subject line suggestions, opening greeting variations, body structure, and closing options. Make it adaptable by highlighting areas that need customization.

# %%
#graph to see the score distribution before and after reranking for Config A
import matplotlib.pyplot as plt
scores_before = [c["similarity"] for c in candidates["config_a_candidates"]]
scores_after = [item["rerank_score"] for item in reranked_a]
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(scores_before, bins=20, color='skyblue', edgecolor='black')
plt.title("Similarity Scores Before Reranking (Config A)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Frequency")
plt.subplot(1, 2, 2)
plt.hist(scores_after, bins=20, color='salmon', edgecolor='black')
plt.title("Rerank Scores After Reranking (Config A)")
plt.xlabel("Rerank Score")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# Now we want to analyze the reranker performance compared to the vector search for the top 10 among the 50 best ones found by vector search itself. As evaluation metrics we use NDCG, RR and P@10.

# %%
def metric_calculator(results, relevant_ids, k):
    p = precision_at_k(results, set(relevant_ids), k=k)
    rr = reciprocal_rank(results, set(relevant_ids))
    ndcg = NDCG(results, set(relevant_ids), k=k)
    return p, rr, ndcg




def evaluate_vector_vs_reranker(ground_truth, candidate_k=50, top_k=10):
    rows = []
    for query, relevant_ids in ground_truth.items():
        if not relevant_ids:
            continue
        relevant_ids_set = set(str(x) for x in relevant_ids)
        res_a, _ = retrieve_chromadb(query,config_a_chromadb,bge_model,top_k=candidate_k)
        res_b, _ = retrieve_chromadb(query,config_b_chromadb,e5_model,top_k=candidate_k,query_prefix="query: ")
        vector_a_results = res_a[:top_k]
        vector_b_results = res_b[:top_k]
        reranked_a = rerank_candidates(query,res_a,top_k=top_k)
        reranked_b = rerank_candidates(query,res_b,top_k=top_k)
        reranked_a_results = [item["candidate"] for item in reranked_a]
        reranked_b_results = [item["candidate"] for item in reranked_b]
        row = {"query": query}
        systems = {"vector_a": vector_a_results,"vector_b": vector_b_results,"rerank_a": reranked_a_results,"rerank_b": reranked_b_results}
        for system_name, results in systems.items():
            metrics = metric_calculator(results,relevant_ids_set,top_k)
            for metric_name, value in zip(["precision", "reciprocal_rank", "ndcg"], metrics):
                row[f"{system_name}_{metric_name}"] = value
        rows.append(row)
    return pd.DataFrame(rows)


reranker_eval = evaluate_vector_vs_reranker(
    GROUND_TRUTH,
    candidate_k=50,
    top_k=10
)

print(reranker_eval)
# Out:
#                                             query  vector_a_precision  \
# 0        create a social media marketing campaign                 0.1
# 1  write a response to a negative customer review                 0.3
# 2      write a SQL query to analyze database data                 0.0
#
#    vector_a_reciprocal_rank  vector_a_ndcg  vector_b_precision  \
# 0                  0.200000       0.131205                 0.1
# 1                  0.333333       0.413839                 0.2
# 2                  0.000000       0.000000                 0.0
#
#    vector_b_reciprocal_rank  vector_b_ndcg  rerank_a_precision  \
# 0                  0.333333       0.169580                 0.0
# 1                  1.000000       0.459972                 0.2
# 2                  0.000000       0.000000                 0.0
#
#    rerank_a_reciprocal_rank  rerank_a_ndcg  rerank_b_precision  \
# 0                       0.0       0.000000                 0.0
# 1                       1.0       0.553146                 0.4
# 2                       0.0       0.000000                 0.0
#
#    rerank_b_reciprocal_rank  rerank_b_ndcg
# 0                       0.0       0.000000
# 1                       1.0       0.843538
# 2                       0.0       0.000000

# %%
#loop over ground truth queries and evaluate the reranker performance compared to the original vector search, using precision@k and reciprocal rank metrics.
def evaluate_vector_vs_reranker(ground_truth, candidate_k=50, top_k=10):
    rows = []
    for query, relevant_ids in ground_truth.items():
        if not relevant_ids:
            continue
        relevant_ids_set = set(relevant_ids)
        res_a, _ = retrieve_chromadb(query, config_a_chromadb, top_k=candidate_k)
        res_b, _ = retrieve_chromadb(query, config_b_chromadb, top_k=candidate_k)
        #vector-only top k
        top_k_a = res_a[:top_k]
        top_k_b = res_b[:top_k]
        #reranked top k
        reranked_a = rerank_candidates(query, res_a, top_k=top_k)
        reranked_b = rerank_candidates(query, res_b, top_k=top_k)
        reranked_a_results= [item["candidate"] for item in reranked_a]
        reranked_b_results = [item["candidate"] for item in reranked_b]
        #calculate metrics
        p_a = precision_at_k(top_k_a, relevant_ids_set, k=top_k)
        rr_a = reciprocal_rank(top_k_a, relevant_ids_set)
        NDCGk_a = NDCG(top_k_a, relevant_ids_set, k=top_k)


        NDCGk_b = NDCG(top_k_b, relevant_ids_set, k=top_k)
        p_b = precision_at_k(top_k_b, relevant_ids_set, k=top_k)
        rr_b = reciprocal_rank(top_k_b, relevant_ids_set)


        p_a_rerank = precision_at_k(reranked_a_results, relevant_ids_set, k=top_k)
        rr_a_rerank = reciprocal_rank(reranked_a_results, relevant_ids_set)
        NDCGk_rerank_a = NDCG(reranked_a_results, relevant_ids_set, k=top_k)

        p_b_rerank = precision_at_k(reranked_b_results, relevant_ids_set, k=top_k)
        rr_b_rerank = reciprocal_rank(reranked_b_results, relevant_ids_set)
        NDCGk_rerank_b = NDCG(reranked_b_results, relevant_ids_set, k=top_k)



        rows.append({
        "query": query,

        "vector_a_p@10": p_a,
        "vector_a_rr": rr_a,
        "vector_a_ndcg@10": NDCGk_a,

        "vector_b_p@10": p_b,
        "vector_b_rr": rr_b,
        "vector_b_ndcg@10": NDCGk_b,

        "rerank_a_p@10": p_a_rerank,
        "rerank_a_rr": rr_a_rerank,
        "rerank_a_ndcg@10": NDCGk_rerank_a,

        "rerank_b_p@10": p_b_rerank,
        "rerank_b_rr": rr_b_rerank,
        "rerank_b_ndcg@10": NDCGk_rerank_b,
        })

    return pd.DataFrame(rows)

reranker_eval = evaluate_vector_vs_reranker(
    GROUND_TRUTH,
    candidate_k=50,
    top_k=10
)

print(reranker_eval[[
    "query",
    "vector_a_p@10", "vector_a_rr", "vector_a_ndcg@10",
    "vector_b_p@10", "vector_b_rr", "vector_b_ndcg@10",
    "rerank_a_p@10", "rerank_a_rr", "rerank_a_ndcg@10",
    "rerank_b_p@10", "rerank_b_rr", "rerank_b_ndcg@10"
]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 61
#      39         rows.append({
#      40         "query": query,
#      41
#    (...)     56         "rerank_b_ndcg@10": NDCGk_rerank_b,
#      57         })
#      59     return pd.DataFrame(rows)
# ---> 61 reranker_eval = evaluate_vector_vs_reranker(
#      62     GROUND_TRUTH,
#      63     candidate_k=50,
#      64     top_k=10
#      65 )
#      67 print(reranker_eval[[
#      68     "query",
#      69     "vector_a_p@10", "vector_a_rr", "vector_a_ndcg@10",
#    (...)     72     "rerank_b_p@10", "rerank_b_rr", "rerank_b_ndcg@10"
#      73 ]])
#
# Cell In[48], line 8, in evaluate_vector_vs_reranker(ground_truth, candidate_k, top_k)
#       6     continue
#       7 relevant_ids_set = set(relevant_ids)
# ----> 8 res_a, _ = retrieve_chromadb(query, config_a_chromadb, top_k=candidate_k)
#       9 res_b, _ = retrieve_chromadb(query, config_b_chromadb, top_k=candidate_k)
#      10 #vector-only top k
#
# TypeError: retrieve_chromadb() missing 1 required positional argument: 'embedding_model'

# %%
#comparison table of vector-only vs reranked results for both Config A and Config B
summary = pd.DataFrame({
    "method": [
        "Config A - Vector Search",
        "Config B - Vector Search",
        "Config A - Reranked",
        "Config B - Reranked",
    ],
    "mean_p@10": [
        reranker_eval["vector_a_p@10"].mean(),
        reranker_eval["vector_b_p@10"].mean(),
        reranker_eval["rerank_a_p@10"].mean(),
        reranker_eval["rerank_b_p@10"].mean(),
    ],
    "mrr": [reranker_eval["vector_a_rr"].mean(),
        reranker_eval["vector_b_rr"].mean(),
        reranker_eval["rerank_a_rr"].mean(),
        reranker_eval["rerank_b_rr"].mean(),
    ],
    "mean_ndcg@10": [
        reranker_eval["vector_a_ndcg@10"].mean(),
        reranker_eval["vector_b_ndcg@10"].mean(),
        reranker_eval["rerank_a_ndcg@10"].mean(),
        reranker_eval["rerank_b_ndcg@10"].mean(),
    ],
})
print(summary)

# %% [markdown]
# FINAL STEP: METADATAS

# %% [markdown]
# ## Metadata-Aware Reranking: Weighted Linear Combination
#
# To incorporate metadata into the ranking process, we apply a weighted linear combination of semantic relevance and engagement signals. The semantic relevance score comes from the cross-encoder reranker, while likes and upvotes are used as metadata-based popularity signals.
#
# Because these values live on different scales, each score is normalized before combination. The reranker score remains the dominant component, while metadata provides a smaller adjustment to promote prompts that are both relevant and positively received by users.

# %%
def minmax_normalize(series):
    min_val = series.min()
    max_val = series.max()

    if max_val == min_val:
        return series.apply(lambda x: 0.0)

    return (series - min_val) / (max_val - min_val)

# Normalize the scores to [0, 1] range for better comparison
summary["mean_p@10_norm"] = minmax_normalize(summary["mean_p@10"])
summary["mrr_norm"] = minmax_normalize(summary["mrr"])
summary["mean_ndcg@10_norm"] = minmax_normalize(summary["mean_ndcg@10"])
print("\nSummary with Normalized Scores:")
print(summary[[
    "method", "mean_p@10", "mean_p@10_norm",
    "mrr", "mrr_norm",
    "mean_ndcg@10", "mean_ndcg@10_norm"
]])

# %%
def metadata_aware_reranker(query, candidates, top_k=10, alpha=0.8, beta=0.1, gamma=0.1):
    reranked = rerank_candidates(query, candidates, top_k=len(candidates))
    reranked_scores=np.array([item["rerank_score"] for item in reranked], dtype=np.float32)
    likes = np.array([item["candidate"]["likes"] for item in reranked], dtype=np.float32)
    upvotes = np.array([item["candidate"]["upvotes"] for item in reranked], dtype=np.float32)
    # Normalize the scores and metadata features
    reranked_scores_norm = minmax_normalize(pd.Series(reranked_scores)).values
    likes_norm = minmax_normalize(pd.Series(np.log1p(likes))).values
    upvotes_norm = minmax_normalize(pd.Series(np.log1p(upvotes))).values
    # Combine the relevance score with metadata features using weighted sum
    combined_score = alpha * reranked_scores_norm + beta * likes_norm + gamma * upvotes_norm
    # Attach combined score to candidates and sort
    for i, item in enumerate(reranked):
        item["combined_score"] = float(combined_score[i])
    return sorted(reranked, key=lambda x: x["combined_score"], reverse=True)[:top_k]

# %%
def alphabetagamma_tuner(query, candidates, ground_truth_ids, top_k=10):
    best_alpha, best_beta, best_gamma = 0.0, 0.0, 0.0
    best_p = -1.0

    for alpha in np.arange(0, 1.01, 0.1):
        for beta in np.arange(0, 1.01 - alpha, 0.1):
            gamma = round(1.0 - alpha - beta, 10)

            if gamma < 0:
                continue

            reranked = metadata_aware_reranker(
                query,
                candidates,
                top_k=top_k,
                alpha=alpha,
                beta=beta,
                gamma=gamma
            )

            reranked_candidates = [
                item["candidate"]
                for item in reranked
            ]

            p = precision_at_k(
                reranked_candidates,
                set(ground_truth_ids),
                k=top_k
            )

            if p > best_p:
                best_p = p
                best_alpha = alpha
                best_beta = beta
                best_gamma = gamma

    return best_alpha, best_beta, best_gamma, best_p

# %%
#test on one query
metadata_reranked_a = metadata_aware_reranker(
    QUERY,
    candidates["config_a_candidates"],
    top_k=5
)

metadata_reranked_b = metadata_aware_reranker(
    QUERY,
    candidates["config_b_candidates"],
    top_k=5
)
print("\nTop 5 metadata-aware reranked candidates from Config A:")
for i, item in enumerate(metadata_reranked_a, start=1):
    c = item["candidate"]
    score = item["combined_score"]
    print(f"\n#{i} | Combined Score: {score:.4f}")
    print(f"ID: {c['id']} | Title: {c['title']} | Category: {c['category']} > {c['subcategory']}")
    print(f"Tags: {c['tags']} | Difficulty: {c['difficulty']} | Likes: {c['likes']} | Upvotes: {c['upvotes']}")
    print(f"Content Preview: {c['content'][:200]}...")

# %%
def evaluate_vector_reranker_metadata(ground_truth, candidate_k=50, top_k=10):
    rows = []
    for query, relevant_ids in ground_truth.items():
        if not relevant_ids:
            continue
        relevant_ids_set = set(relevant_ids)
        res_a, _ = retrieve_chromadb(query, config_a_chromadb, top_k=candidate_k)
        res_b, _ = retrieve_chromadb(query, config_b_chromadb, top_k=candidate_k)
        #metadata-aware reranked top k
        metadata_reranked_a = metadata_aware_reranker(query, res_a, top_k=top_k)
        metadata_reranked_b = metadata_aware_reranker(query, res_b, top_k=top_k)
        metadata_reranked_a_results = [item["candidate"] for item in metadata_reranked_a]
        metadata_reranked_b_results = [item["candidate"] for item in metadata_reranked_b]
        #calculate metrics
        p_a_metadata = precision_at_k(metadata_reranked_a_results, relevant_ids_set, k=top_k)
        rr_a_metadata = reciprocal_rank(metadata_reranked_a_results, relevant_ids_set)
        NDCGk_a_metadata = NDCG(metadata_reranked_a_results, relevant_ids_set, k=top_k)

        p_b_metadata = precision_at_k(metadata_reranked_b_results, relevant_ids_set, k=top_k)
        rr_b_metadata = reciprocal_rank(metadata_reranked_b_results, relevant_ids_set)
        NDCGk_b_metadata = NDCG(metadata_reranked_b_results, relevant_ids_set, k=top_k)

        rows.append({
            "query": query,
            "metadata_rerank_a_p@10": p_a_metadata,
            "metadata_rerank_a_rr": rr_a_metadata,
            "metadata_rerank_a_ndcg@10": NDCGk_a_metadata,
            "metadata_rerank_b_p@10": p_b_metadata,
            "metadata_rerank_b_rr": rr_b_metadata,
            "metadata_rerank_b_ndcg@10": NDCGk_b_metadata,
        })

    return pd.DataFrame(rows)

# %%
metadata_eval = evaluate_vector_reranker_metadata(
    GROUND_TRUTH,
    candidate_k=50,
    top_k=10
)

print(metadata_eval[[
    "query",
    "metadata_rerank_a_p@10", "metadata_rerank_a_rr", "metadata_rerank_a_ndcg@10",
    "metadata_rerank_b_p@10", "metadata_rerank_b_rr", "metadata_rerank_b_ndcg@10"
]])

full_eval= reranker_eval.merge(
    metadata_eval,
    on="query",
    how="inner"
)
print(full_eval[[
    "query",
    "vector_a_p@10", "vector_a_rr", "vector_a_ndcg@10",
    "vector_b_p@10", "vector_b_rr", "vector_b_ndcg@10",
    "rerank_a_p@10", "rerank_a_rr", "rerank_a_ndcg@10",
    "rerank_b_p@10", "rerank_b_rr", "rerank_b_ndcg@10",
    "metadata_rerank_a_p@10", "metadata_rerank_a_rr", "metadata_rerank_a_ndcg@10",
    "metadata_rerank_b_p@10", "metadata_rerank_b_rr", "metadata_rerank_b_ndcg@10"
]])


metadata_summary = pd.DataFrame({
    "method": [
        "Config A - Vector Search",
        "Config B - Vector Search",
        "Config A - Reranked",
        "Config B - Reranked",
        "Config A - Metadata-aware Rerank",
        "Config B - Metadata-aware Rerank",
    ],
    "mean_p@10": [
        full_eval["vector_a_p@10"].mean(),
        full_eval["vector_b_p@10"].mean(),
        full_eval["rerank_a_p@10"].mean(),
        full_eval["rerank_b_p@10"].mean(),
        full_eval["metadata_rerank_a_p@10"].mean(),
        full_eval["metadata_rerank_b_p@10"].mean(),
    ],
    "mrr": [
        full_eval["vector_a_rr"].mean(),
        full_eval["vector_b_rr"].mean(),
        full_eval["rerank_a_rr"].mean(),
        full_eval["rerank_b_rr"].mean(),
        full_eval["metadata_rerank_a_rr"].mean(),
        full_eval["metadata_rerank_b_rr"].mean(),
    ],
    "mean_ndcg@10": [
        full_eval["vector_a_ndcg@10"].mean(),
        full_eval["vector_b_ndcg@10"].mean(),
        full_eval["rerank_a_ndcg@10"].mean(),
        full_eval["rerank_b_ndcg@10"].mean(),
        full_eval["metadata_rerank_a_ndcg@10"].mean(),
        full_eval["metadata_rerank_b_ndcg@10"].mean(),
    ],
})

print("\nFull Retrieval/Reranking Summary:")
print(metadata_summary)

print("\nMetadata-aware Reranking Summary:")
print(metadata_summary)

# %% [markdown]
# ## FUTURE WORK
#
# Right now this approach is impossible without an expanded ground truth that due to time constraint isn't possible to enlarge in a significant way. We will still leave it here as a proposal of work,

# %%
#build a dictionary of metadatas

def candidate_metadata_map(query, candidate, config_label, rerank_score, relevant_ids):
    return {
        "query": query,
        "candidate_id": candidate["id"],
        "title": candidate["title"],
        "category": candidate["category"],
        "subcategory": candidate["subcategory"],
        "tags": candidate["tags"],
        "difficulty": candidate["difficulty"],
        "likes": candidate["likes"],
        "upvotes": candidate["upvotes"],
        "rerank_score": rerank_score,
        "is_relevant": int(candidate["id"] in relevant_ids), #convert to 0 1
        "config": config_label,
        "vector_similarity": candidate.get("similarity", 0)
    }

#example usage of the candidate_metadata_map function
example_candidate = candidates["config_a_candidates"][0]
example_metadata = candidate_metadata_map(
    query=QUERY,
    candidate=example_candidate,
    config_label="Config A",
    rerank_score=reranked_a[0]["rerank_score"],
    relevant_ids=GROUND_TRUTH.get(QUERY, [])
)
print("\nExample candidate metadata map:")
print(example_metadata)

# %%
def build_rows_for_config(query, relevant_ids, collection,config_label, candidate_k=50):
    results, _ = retrieve_chromadb(query, collection, top_k=candidate_k)
    reranked = rerank_candidates(query, results, top_k=len(results))
    rows = []
    for item in reranked:
        candidate = item["candidate"]
        rerank_score = item["rerank_score"]
        row = candidate_metadata_map(query, candidate, config_label, rerank_score, relevant_ids)
        rows.append(row)
    return rows

# %%
def build_learning_data(ground_truth,  candidate_k=50):
    all_rows = []
    for query, relevant_ids in ground_truth.items():
        if not relevant_ids:
            continue
        relevant_ids_set = set(relevant_ids)
        rows_a = build_rows_for_config(query, relevant_ids_set, config_a_chromadb, "Config A", candidate_k)
        rows_b = build_rows_for_config(query, relevant_ids_set, config_b_chromadb, "Config B", candidate_k)
        all_rows.extend(rows_a)
        all_rows.extend(rows_b)
    return pd.DataFrame(all_rows)

# %%
#we want to see likes and upvotes distribution in the learning data so that we understand if there is a need to normalize these features before training the reranker
learning_data = build_learning_data(GROUND_TRUTH, candidate_k=50)
print(learning_data[["likes", "upvotes"]].describe())
#plot violin plots for likes and upvotes to see their distribution and identify if there are outliers that might require normalization
import seaborn as sns
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.violinplot(y=learning_data["likes"], color="skyblue")
plt.title("Distribution of Likes in Learning Data")
plt.subplot(1, 2, 2)
sns.violinplot(y=learning_data["upvotes"], color="salmon")
plt.title("Distribution of Upvotes in Learning Data")
plt.tight_layout()
plt.show()
#boxplot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=learning_data["likes"], color="skyblue")
plt.title("Boxplot of Likes in Learning Data")
plt.subplot(1, 2, 2)
sns.boxplot(y=learning_data["upvotes"], color="salmon")
plt.title("Boxplot of Upvotes in Learning Data")
plt.tight_layout()
plt.show()

# %%
def add_features(df):
    df["difficulty_level"] = df["difficulty"].map({"unknown": 0, "beginner": 1,
        "intermediate": 2,
        "advanced": 3,
        "expert": 4,
    }).fillna(0).astype(int)
    df["config_encoded"] = df["config"].map({
        "Config A": 0,
        "Config B": 1,
    }).fillna(0).astype(int)
    df["log_likes"] = np.log1p(df["likes"])
    df["log_upvotes"] = np.log1p(df["upvotes"])
    return df

#apply the feature engineering function to the learning data
learning_data = add_features(learning_data)
print(learning_data[[
    "difficulty", "difficulty_level", "config", "config_encoded", "likes", "log_likes", "upvotes", "log_upvotes"
]].head())

#violin and boxplots for the engineered features
plt.figure(figsize=(16, 10))
plt.subplot(2, 2, 1)
sns.violinplot(x=learning_data["difficulty"], y=learning_data["rerank_score"], color="lightgreen")
plt.title("Rerank Score Distribution by Difficulty Level")
plt.subplot(2, 2, 2)
sns.violinplot(x=learning_data["config"], y=learning_data["rerank_score"], color="lightblue")
plt.title("Rerank Score Distribution by Config")
plt.subplot(2, 2, 3)
sns.boxplot(x=learning_data["difficulty"], y=learning_data["rerank_score"], color="lightgreen")
plt.title("Boxplot of Rerank Scores by Difficulty Level")
plt.subplot(2, 2, 4)
sns.boxplot(x=learning_data["config"], y=learning_data["rerank_score"], color="lightblue")
plt.title("Boxplot of Rerank Scores by Config")
plt.tight_layout()
plt.show()

# %%
#split by query to avoid data leakage between train and test sets, since candidates from the same query are not independent (they share the same relevance signal)
from sklearn.model_selection import train_test_split
queries = learning_data["query"].unique()
train_queries, test_queries = train_test_split(queries, test_size=0.2, random_state=67)
train_data = learning_data[learning_data["query"].isin(train_queries)].reset_index(drop=True)
test_data = learning_data[learning_data["query"].isin(test_queries)].reset_index(drop=True)
print(f"Train set: {len(train_data)} samples | Test set: {len(test_data)} samples")

# %%
print(f"Train queries: {len(train_queries)}")
print(f"Test queries: {len(test_queries)}")

print("\nTrain label distribution:")
print(train_data["is_relevant"].value_counts())

print("\nTest label distribution:")
print(test_data["is_relevant"].value_counts())
if train_data["is_relevant"].sum() == 0:
    print("Warning: no relevant examples in train set")

if test_data["is_relevant"].sum() == 0:
    print("Warning: no relevant examples in test set")
